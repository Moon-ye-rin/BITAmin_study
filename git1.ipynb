# %%
import pandas as pd

profile = ['2026-03-25', '문예린', '2003-11-06', 'ISTJ']
profile = pd.Series(profile)

# %%
profile
# Out:
# 0    2026-03-25
# 1           문예린
# 2    2003-11-06
# 3          ISTJ
# dtype: object
